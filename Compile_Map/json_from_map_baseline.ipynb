# %%
from collections import OrderedDict 

# Direction is direction you must cut the note 
# 0 - Up, 1 - Down, 2 - Right, 3 - Left,
# 4 - Down-Right, 5 - Down-Left, 6 - Up-Right, 7 - Up-Left
# 8 - No Direction
inverse_note_dir = { # Direction is the direction one must cut the note 
    "Up" : 0,
    "Down" : 1,
    "Right" : 2,
    "Left" : 3,
    "Down-Right" : 4,
    "Down-Left" : 5,
    "Up-Right" : 6,
    "Up-Left" : 7,
    "No" : 8,
}

def make_note_row(notes_types):
    outlist = list()
    for time,val in notes_types.items():
        time = key
        for row in range(len(val)):
            for col in range(len(row)):
                xindex = 0
                yindex = 0
                colour = 0
                cut_direction = 0
                check_val = val[row][col].split(" ")
                if len(check_val) == 3:
                    continue
                elif check_val[0] == "Red":
                    colour = 0
                elif check_val[0] == "Blue":
                    colour = 1
                else:
                    continue
                ordered_data = OrderedDict()

                cut_direction = inverse_note_dir[check_val[1]]
                xindex = row
                yindex = col
                ordered_data["_time"] = time
                ordered_data["_value"] = colour
                ordered_data["_type"] = cut_direction
                outlist.append(r'"_time":{},"_lineIndex":{},"_lineLayer:"{},"_type::{},"_cutDirection"{}'.format(time,xindex,yindex,colour,cut_direction))

    return outlist
